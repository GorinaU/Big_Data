# %%
#Подключаем библиотеки
import numpy as np
import pandas as pd

#Читаем данные с github.com/junaart/DataForR
data=pd.read_excel("https://github.com/junaart/ForStudents/blob/master/Big_Data/Seminar_3/demo26.xlsx?raw=true",engine="openpyxl")

#Отображаем данные
display(data)
# Out:
#                                Год   1990   1995   2000   2001   2002   2003  \
# 0                    Все население  69.19  64.52  65.34  65.23  64.95  64.84
# 1                      Все мужчины  63.73  58.12  59.03  58.92  58.68  58.53
# 2                      Все женщины  74.30  71.59  72.26  72.17  71.90  71.85
# 3          Все городское население  69.55  64.70  65.69  65.57  65.40  65.36
# 4  Все городское население мужчины  64.31  58.30  59.35  59.23  59.09  59.01
# 5  Все городское население женщины  74.34  71.64  72.46  72.37  72.18  72.20
# 6           Все сельское население  67.97  63.99  64.34  64.25  63.68  63.34
# 7   Все сельское население мужчины  62.03  57.64  58.14  58.07  57.54  57.20
# 8   Все сельское население женщины  73.95  71.40  71.66  71.57  71.09  70.81
#
#     2004   2005   2006  ...   2010       2011   2012   2013   2014   2015  \
# 0  65.31  65.37  66.69  ...  68.94  69.831495  70.24  70.76  70.93  71.39
# ...

# %%
#Создать фрейм данных, транспонируя исходный фрейм данных, присвоив имена столбцов
dd=(data.T).iloc[0:,0:5]
dd.columns=['FIRST', 'SECOND', 'THIRD', 'FOURTH', 'FIFTH']
display(dd)
# Out:
#               FIRST       SECOND        THIRD                   FOURTH  \
# Год   Все население  Все мужчины  Все женщины  Все городское население
# 1990          69.19        63.73         74.3                    69.55
# 1995          64.52        58.12        71.59                     64.7
# 2000          65.34        59.03        72.26                    65.69
# 2001          65.23        58.92        72.17                    65.57
# 2002          64.95        58.68         71.9                     65.4
# 2003          64.84        58.53        71.85                    65.36
# 2004          65.31        58.91        72.36                    65.87
# 2005          65.37        58.92        72.47                     66.1
# 2006          66.69        60.43        73.34                    67.43
# 2007          67.61        61.46        74.02                    68.37
# 2008          67.99        61.92        74.28                    68.77
# ...

# %%
#Отобрать года, для которых значение во втором столбце больше среднего значения этого столбца.
ddd=dd.iloc[1:]
ddd.SECOND.mean()
# Out:
# 62.70681285629318

# %%
ddd[ddd.SECOND > ddd.SECOND.mean()].index
#sr = [Все мужчины] > [Все мужчины].mean()[Все мужчины]
#display(sr)
# Out:
# Index([1990, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], dtype='object')

# %%
#Вывести на экран все строки фрейма за четные года.
ll=pd.DataFrame(columns=ddd.columns)
for i in list(ddd.index):
    if i%2==0:
        ll.loc[i]=ddd.loc[i]
ll
# Out:
#       FIRST  SECOND  THIRD  FOURTH  FIFTH
# 1990  69.19   63.73  74.30   69.55  64.31
# 2000  65.34   59.03  72.26   65.69  59.35
# 2002  64.95   58.68  71.90   65.40  59.09
# 2004  65.31   58.91  72.36   65.87  59.42
# 2006  66.69   60.43  73.34   67.43  61.12
# 2008  67.99   61.92  74.28   68.77  62.67
# 2010  68.94   63.09  74.88   69.69  63.82
# 2012  70.24   64.56  75.86   70.83  65.10
# 2014  70.93   65.29  76.47   71.44  65.75
# 2016  71.87   66.50  77.06   72.35  66.91
# 2018  72.91   67.75  77.82   73.34  68.11

# %%
#Построить график по оси x - года, по оси y значения третьего столбца.
import matplotlib as ml

ddd.THIRD.plot()
# Out:
# <AxesSubplot:>

# %%
#Добавить к фрейму новый столбец категориальных данных по принципу: 
#если значение третьего столбца в строке больше медианного значения этого столбца и значение 
#четвертого столбца этой строки больше медианного значения этого столбца, то в новый столбец пишем 'good', 
#в противном случае пишем 'bad'.
med3=ddd.THIRD.median()
med4=ddd.FOURTH.median()

for i in list(ddd.index):
    if (ddd.loc[i][2]>med3) & (ddd.loc[i][3]>med4):
        ddd.loc[i]['g_b'] = 'good'
    else:
        ddd.loc[i]['g_b'] = 'bad'
ddd
# Out:
#         FIRST   SECOND    THIRD   FOURTH   FIFTH
# 1990    69.19    63.73     74.3    69.55   64.31
# 1995    64.52    58.12    71.59     64.7    58.3
# 2000    65.34    59.03    72.26    65.69   59.35
# 2001    65.23    58.92    72.17    65.57   59.23
# 2002    64.95    58.68     71.9     65.4   59.09
# 2003    64.84    58.53    71.85    65.36   59.01
# 2004    65.31    58.91    72.36    65.87   59.42
# 2005    65.37    58.92    72.47     66.1   59.58
# 2006    66.69    60.43    73.34    67.43   61.12
# 2007    67.61    61.46    74.02    68.37    62.2
# 2008    67.99    61.92    74.28    68.77   62.67
# 2009    68.78    62.87    74.79    69.57   63.65
# 2010    68.94    63.09    74.88    69.69   63.82
# 2011  69.8315  64.0399  75.6056  70.5091  64.669
# 2012    70.24    64.56    75.86    70.83    65.1
# 2013    70.76    65.13     76.3    71.33   65.64
# 2014    70.93    65.29    76.47    71.44   65.75
# 2015    71.39    65.92    76.71    71.91   66.38
# ...
