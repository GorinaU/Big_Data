# %%
import pymysql

connection = pymysql.connect(
    host='localhost',
    user='root',
    password='',
    db = 'dot',
    charset='utf8',
)

# %%
connection.query("use dot;")
# Out:
# 0

# %%
import pandas as pd
data=pd.read_csv("https://raw.githubusercontent.com/junaart/ForStudents/master/NoSQL/Zachet/data.csv",delimiter=",")
display(data)
# Out:
#               shrimp            almonds      avocado    vegetables mix  \
# 0            burgers          meatballs         eggs               NaN
# 1            chutney                NaN          NaN               NaN
# 2             turkey            avocado          NaN               NaN
# 3      mineral water               milk   energy bar  whole wheat rice
# 4     low fat yogurt                NaN          NaN               NaN
# ...              ...                ...          ...               ...
# 7495          butter         light mayo  fresh bread               NaN
# 7496         burgers  frozen vegetables         eggs      french fries
# 7497         chicken                NaN          NaN               NaN
# 7498        escalope          green tea          NaN               NaN
# 7499            eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#      green grapes whole weat flour yams cottage cheese energy drink  \
# ...

# %%
cursor = connection.cursor()
cursor.execute("show tables")
# Out:
# 2

# %%
table = cursor.fetchall()
table
# Out:
# (('my',), ('tbl',))

# %%
# select_my = "SELECT * from my"
# select_my
cursor.execute("SELECT * from `my`;")
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11468/3357254396.py in <module>
#       1 # select_my = "SELECT * from my"
#       2 # select_my
# ----> 3 cursor.execute("SELECT * from `my`;")
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# ...

# %%
import os
import csv
import glob
import pymysql

# %%
list(my)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11468/1336634228.py in <module>
# ----> 1 list(my)
#
# NameError: name 'my' is not defined

# %%
cursor = connection.cursor()
 
with open("C:\data.csv", "r") as csv_file:
 
    csv_data =csv.reader(csv_file)
    row_count = 0

    fields = pd.DataFrame({'a1,', 'b2,', 'c3,', 'd4,', 'e5,', 'f6,', 'g7,', 'h8,', 'i9,', 'j10,', 'k11,', 'l12,', 'm13,', 'n14,', 'o15,', 'p16,', 'q17,', 'r18,', 's19,', 't20'}).isnull().sum(axis=1)
    print(fields.head())
    print('\n')
    
#     row = pd.DataFrame({'%s,'.join(row)}).isnull()
#     row = pd.DataFrame({','.join(row)+'null '*(20-len(row))}).isnull()
#     print(list(row))
#     print('\n')
    
    for row in csv_data:
        row = pd.DataFrame({'%s,'.join(row)}).isnull()
        print(row)
        if row_count != 0:
            try:
                cursor.execute('INSERT INTO my({''.join(fields)}) VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)', row)
                row_count += 1
            except Exception:
                pass
            
connection.commit()
print(cursor.rowcount, "was inserted.")
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64
#
#
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# 0  False
#        0
# ...

# %% [markdown]
# <ul>
# <li>2. На языке Python, прочитав данные из файла data.csv, записать их в таблицу созданной базы данных dot.</li>
# </ul>

# %%
import csv
import mysql.connector

cursor = connection.cursor()

with open("C:\data.csv") as csv_file:
 
    csv_data =csv.reader(csv_file)
    row_count = 0
    fields = ['id']+['my1', 'my2', 'my3', 'my4', 'my5', 'my6', 'my7', 'my8', 'my9', 'my10', 'my11', 'my12', 'my13', 'my14', 'my15', 'my16', 'my17', 'my18', 'my19', 'my20']
    print(fields)
    print('\n')
    for row in csv_data:
        row = [f'"{x}"' for x in row]
#         row = [f'"{x+1}"' for x in len(list(row[0:min(20,len(row))]))]
        print(row)
        print('\n')
        row = ",".join(row)+",null"*(20-len(row))
        print(row)
        print('\n')
#         cursor.execute(f'INSERT INTO my ({", ".join(fields)}) VALUES ({row_count}, {row});')
        print('\n')
        quer = f"INSERT INTO my ({','.join(fields)}) VALUES ({row_count}, {row});"
        row_count += 1
        cursor.execute(quer)
        
connection.commit()
# Out:
# ['id', 'my1', 'my2', 'my3', 'my4', 'my5', 'my6', 'my7', 'my8', 'my9', 'my10', 'my11', 'my12', 'my13', 'my14', 'my15', 'my16', 'my17', 'my18', 'my19', 'my20']
#
#
# ['"shrimp"', '"almonds"', '"avocado"', '"vegetables mix"', '"green grapes"', '"whole weat flour"', '"yams"', '"cottage cheese"', '"energy drink"', '"tomato juice"', '"low fat yogurt"', '"green tea"', '"honey"', '"salad"', '"mineral water"', '"salmon"', '"antioxydant juice"', '"frozen smoothie"', '"spinach"', '"olive oil"']
#
#
# "shrimp","almonds","avocado","vegetables mix","green grapes","whole weat flour","yams","cottage cheese","energy drink","tomato juice","low fat yogurt","green tea","honey","salad","mineral water","salmon","antioxydant juice","frozen smoothie","spinach","olive oil"
#
#
#
#
# ['"burgers"', '"meatballs"', '"eggs"']
#
#
# "burgers","meatballs","eggs",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null
#
#
#
#
# ['"chutney"']
#
#
# ...

# %%
display(quer)
# Out:
# 'INSERT INTO my (id,my1,my2,my3,my4,my5,my6,my7,my8,my9,my10,my11,my12,my13,my14,my15,my16,my17,my18,my19,my20) VALUES (7500, "eggs","frozen smoothie","yogurt cake","low fat yogurt",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null);'

# %% [markdown]
# ### ниже работает

# %%
import csv

f = lambda words: '"' + words + '"'
temp = 0
with open("C:\data.csv") as File:
    for row in File:
        words_arr = row.split(',')
        words_arr = list(map(f, words_arr[0: min(20, len(words_arr))]))
        words_arr[-1] = words_arr[-1].replace("\n", "")
        print(words_arr)
        print('\n')

        columns = ["id_f"] + [f"x{j + 1}" for j in range(len(words_arr))]
        print(columns)
        print('\n')
        
        quer = f"INSERT INTO tbl ({','.join(columns)}) VALUES ({temp}, {','.join(words_arr)});"
        print(quer)
        print('\n')
        temp += 1
        print(temp)
        print('\n')
        cursor.execute(quer)
# Out:
# ['"shrimp"', '"almonds"', '"avocado"', '"vegetables mix"', '"green grapes"', '"whole weat flour"', '"yams"', '"cottage cheese"', '"energy drink"', '"tomato juice"', '"low fat yogurt"', '"green tea"', '"honey"', '"salad"', '"mineral water"', '"salmon"', '"antioxydant juice"', '"frozen smoothie"', '"spinach"', '"olive oil"']
#
#
# ['id_f', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x20']
#
#
# INSERT INTO tbl (id_f,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,x16,x17,x18,x19,x20) VALUES (0, "shrimp","almonds","avocado","vegetables mix","green grapes","whole weat flour","yams","cottage cheese","energy drink","tomato juice","low fat yogurt","green tea","honey","salad","mineral water","salmon","antioxydant juice","frozen smoothie","spinach","olive oil");
#
#
# 1
# ---------------------------------------------------------------------------
# ...

# %%
import atoti as tt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11468/4109374974.py in <module>
# ----> 1 import atoti as tt
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\atoti\__init__.py in <module>
#      11 typecheck(BaseSession)
#      12
# ---> 13 from atoti_query import (
#      14     BasicAuthentication as BasicAuthentication,
#      15     OAuth2ResourceOwnerPasswordAuthentication as OAuth2ResourceOwnerPasswordAuthentication,
#
# ImportError: cannot import name 'OAuth2ResourceOwnerPasswordAuthentication' from 'atoti_query' (C:\Users\Hz\AppData\Local\Programs\Python\Python39\lib\site-packages\atoti_query\__init__.py)

# %%
pip list
# Out:
# Package                           Version
# --------------------------------- ---------
# Note: you may need to restart the kernel to use updated packages.
# anyio                             3.5.0
# argon2-cffi                       21.1.0
# arrow                             1.2.1
# atomicwrites                      1.4.0
# atoti                             0.6.6
# atoti-core                        0.6.6
# atoti-jupyterlab                  0.6.6
# atoti-query                       0.6.6
# attrs                             21.2.0
# Babel                             2.9.1
# backcall                          0.2.0
# bleach                            4.1.0
# certifi                           2021.10.8
# cffi                              1.14.6
# chardet                           3.0.4
# charset-normalizer                2.0.9
# click                             8.0.3
# cloudpickle                       2.0.0
# colorama                          0.4.4
# ...

# %%
connection.commit()

# %%
connection.commit()

# %%
connection.commit()

# %%
import redis
r=redis.Redis()
r=redis.Redis(host='localhost',port=7777, db=0)
dir(r)
# Out:
# ['RESPONSE_CALLBACKS',
#  '__class__',
#  '__contains__',
#  '__del__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_disconnect_raise',
#  '_georadiusgeneric',
#  '_geosearchgeneric',
#  '_send_command_parse_response',
#  '_zaggregate',
#  '_zrange',
#  'acl_cat',
#  'acl_deluser',
#  'acl_genpass',
#  'acl_getuser',
#  'acl_help',
#  'acl_list',
#  'acl_load',
#  'acl_log',
#  'acl_log_reset',
#  'acl_save',
#  'acl_setuser',
#  'acl_users',
#  'acl_whoami',
#  'append',
#  'bgrewriteaof',
#  'bgsave',
#  'bitcount',
#  'bitfield',
# ...

# %%
import rediscluster

from .redis import *  #For importing something from your redis.py
from redis import ConnectionPool  #For importing from redis module

redcon = rediscluster.RedisCluster(host='localhost',port=8000)
redcon.flushdb()
print(redcon)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11468/3216640485.py in <module>
# ----> 1 import rediscluster
#       2
#       3 from .redis import *  #For importing something from your redis.py
#       4 from redis import ConnectionPool  #For importing from redis module
#       5
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\rediscluster\__init__.py in <module>
#       5
#       6 # rediscluster imports
# ----> 7 from rediscluster.client import RedisCluster
#       8 from rediscluster.connection import (
#       9     ClusterBlockingConnectionPool,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\rediscluster\client.py in <module>
#      10
#      11 # rediscluster imports
# ---> 12 from .connection import (
#      13     ClusterConnection,
#      14     ClusterConnectionPool,
#
# ...

# %% [markdown]
# <ul>
# <li>8. Развернуть кластерную инфраструктуру MongoDB из 2 кластеров по одному мастеру и одной реплике в каждом, с двумя конфигурационными серверами и двумя маршрутизаторами.
# </li>
# </ul>

# %%
import random

def randomSentence(sentenceLength):
    keys = redcon.keys()
    # беру случайным образом указанное количество ключей
    ks = random.choices(keys,k=sentenceLength)
    # в ключах не должно быть хеш-таблицы 'rowSizes'
    while structName in [x.decode("UTF-8") for x in ks]:
        ks = random.choices(keys,k=sentenceLength)
    # создаю список из слуйчайно выбранного слова из списка по каждому из полученных ключей
    vals=[random.choice(redcon.lrange(k,1,-1)).decode("UTF-8") for k in ks]
    # объединяю слова через пробел
    return ' '.join(vals)

for i in range(5):
    print(i+1," ::: ",randomSentence(random.randint(3,10)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11468/2547625144.py in <module>
#      14
#      15 for i in range(5):
# ---> 16     print(i+1," ::: ",randomSentence(random.randint(3,10)))
#
# ~\AppData\Local\Temp/ipykernel_11468/2547625144.py in randomSentence(sentenceLength)
#       2
#       3 def randomSentence(sentenceLength):
# ----> 4     keys = redcon.keys()
#       5     # беру случайным образом указанное количество ключей
#       6     ks = random.choices(keys,k=sentenceLength)
#
# NameError: name 'redcon' is not defined

# %% [markdown]
# <ul>
# <li>9. С использованием функции, созданной в пункте 7, сгенерить 1000 строк. Каждую строку записать в MongoDB в виде отдельного документа, в котором каждое слово строки записывается под своим атрибутом. Например, строка "I am happy" превращается в документ {name1:"I", name2:"am", name3:"happy"}</li>
# </ul>

# %%
import pymongo

mcon = pymongo.MongoClient("localhost",40000)
print(mcon)
# Out:
# MongoClient(host=['localhost:40000'], document_class=dict, tz_aware=False, connect=True)

# %%
dbName = 'mydot'
collectionName = 'mymy'

db = mcon[dbName]
collect = db[collectionName]

print(db)
print(collect)
# Out:
# Database(MongoClient(host=['localhost:40000'], document_class=dict, tz_aware=False, connect=True), 'mydot')
# Collection(Database(MongoClient(host=['localhost:40000'], document_class=dict, tz_aware=False, connect=True), 'mydot'), 'mymy')

# %%
for i in range(1000):
    s = randomSentence(random.randint(3,5))
    w = s.split(' ')
    
    attrs = [f"name{x}" for x in range(len(w))]
    
    collect.insert_one({k:v for k,v in zip(attrs,w) })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11468/3944125407.py in <module>
#       1 for i in range(1000):
# ----> 2     s = randomSentence(random.randint(3,5))
#       3     w = s.split(' ')
#       4
#       5     attrs = [f"name{x}" for x in range(len(w))]
#
# NameError: name 'randomSentence' is not defined

# %%
connection.commit()
